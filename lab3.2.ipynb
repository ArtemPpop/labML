# %%
text = """программирование интересное занятие
программирование требует вниманиякаждое слово имеет значение"""

with open('text.txt', 'w', encoding='utf-8') as f:
    f.write(text)

# %%
import re
from collections import Counter
with open('text.txt', 'r', encoding='utf-8') as f:
    text = f.read()
words = re.findall(r'[а-яА-ЯёЁ]+', text)
words = [w.lower() for w in words]
max_len = max(len(w) for w in words)
longest = [w for w in set(words) if len(w) == max_len]
count = Counter(words)
for word in longest:
    print(f"Самое длинное слово: '{word}'")
    print(f"Встречается: {count[word]} раз(а)")
# Out:
# Самое длинное слово: 'программирование'
# Встречается: 2 раз(а)
